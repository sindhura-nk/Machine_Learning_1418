# %% [markdown]
# ## Logistic Regression: Classification Problem

# %% [markdown]
# ## Data Gathering

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
path = r"https://raw.githubusercontent.com/sindhura-nk/Datasets/refs/heads/main/iris.csv"
import pandas as pd
df = pd.read_csv(path)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# check for missing data
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# check for duplicated rows
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## Separate X and Y features
#
# Y : Species
# X : all remaining features, sepal length/width, petal length/width

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
X = df.drop(columns=['species'])
Y = df[['species']]

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
Y.head()
# Out:
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ## Data Preprocessing and Data Cleaning

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
pre = make_pipeline(
    SimpleImputer(strategy='median'),
    StandardScaler()
).set_output(transform='pandas')

# %%
X_pre = pre.fit_transform(X)
X_pre.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0     -0.898033     1.012401     -1.333255    -1.308624
# 1     -1.139562    -0.137353     -1.333255    -1.308624
# 2     -1.381091     0.322549     -1.390014    -1.308624
# 3     -1.501855     0.092598     -1.276496    -1.308624
# 4     -1.018798     1.242352     -1.333255    -1.308624

# %% [markdown]
# ## Train Test Split
# rate at which you can divide:
#
# 100%
#
# 60 % training 40% testing
#
# 70% training 30% testing
#
# 80% training 20% testing

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# random_state = this is generally used for reproducing model results

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X_pre,Y,train_size=0.7,test_size=0.3,random_state=21)

# %%
xtrain.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 36     -0.414976     1.012401     -1.390014    -1.308624
# 37     -1.139562     1.242352     -1.333255    -1.440192
# 13     -1.864149    -0.137353     -1.503531    -1.440192
# 68      0.430375    -1.976960      0.426261     0.401770
# 11     -1.260327     0.782450     -1.219738    -1.308624

# %%
xtrain.index
# Out:
# Index([ 36,  37,  13,  68,  11,  52,  49,  65, 117,  55,
#        ...
#        122,  61, 110,  72,  98, 120, 112,  48,   4,  56],
#       dtype='int64', length=104)

# %%
xtest.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 92     -0.052682    -1.057157      0.142468     0.007064
# 44     -0.898033     1.702254     -1.049462    -1.045486
# 7      -1.018798     0.782450     -1.276496    -1.308624
# 21     -0.898033     1.472303     -1.276496    -1.045486
# 95     -0.173447    -0.137353      0.255985     0.007064

# %%
ytrain.head()
# Out:
#        species
# 36      setosa
# 37      setosa
# 13      setosa
# 68  versicolor
# 11      setosa

# %%
ytest.head()
# Out:
#        species
# 92  versicolor
# 44      setosa
# 7       setosa
# 21      setosa
# 95  versicolor

# %% [markdown]
# ## Build the model

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
model.classes_
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
ypred_train = model.predict(xtrain)

# %%
yprob_train = model.predict_proba(xtrain)

# %%
yprob_train[0]
# Out:
# array([9.67343450e-01, 3.26556334e-02, 9.16479348e-07])

# %%
model.classes_
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
ypred_train[:5]
# Out:
# array(['setosa', 'setosa', 'setosa', 'versicolor', 'setosa'], dtype=object)

# %%
ytrain.head()
# Out:
#        species
# 36      setosa
# 37      setosa
# 13      setosa
# 68  versicolor
# 11      setosa

# %% [markdown]
# ## Model Evaluation

# %%
model.score(xtrain,ytrain)
# Out:
# 0.9711538461538461

# %%
model.score(xtest,ytest)
# Out:
# 0.9111111111111111

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(model,xtest,ytest)

# %% [markdown]
# ## Classification Report

# %%
ypred_test = model.predict(xtest)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,ypred_test))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        14
#   versicolor       0.93      0.81      0.87        16
#    virginica       0.82      0.93      0.88        15
#
#     accuracy                           0.91        45
#    macro avg       0.92      0.92      0.91        45
# weighted avg       0.92      0.91      0.91        45

# %%
from sklearn.metrics import f1_score
f1_score(ytest,ypred_test,average='macro')
# Out:
# 0.9138888888888889

# %% [markdown]
# ## K-Fold Cross Validation
# ![image.png](attachment:image.png)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model,xtrain,ytrain,scoring='f1_macro') # cv=5 is default number of folds
scores
# Out:
# array([0.94871795, 1.        , 1.        , 0.90277778, 1.        ])

# %%
scores.mean()
# Out:
# np.float64(0.9702991452991453)

# %%
scores2 = cross_val_score(model,xtrain,ytrain,cv=3,scoring='f1_macro') # cv=5 is default number of folds
scores2
# Out:
# array([0.97079365, 1.        , 0.93888889])

# %%
scores2.mean()
# Out:
# np.float64(0.9698941798941799)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## All the scores are greater than 80%(0.80), we can consider this model for final model building

# %%
path2 = r"https://raw.githubusercontent.com/sindhura-nk/Datasets/refs/heads/main/iris_sample.csv"
xnew = pd.read_csv(path2)
xnew.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.5          2.5           4.0          1.3
# 1           6.9          3.1           5.1          2.3
# 2           5.1          2.5           3.0          1.1
# 3           4.4          2.9           NaN          0.2
# 4           5.9          3.0           5.1          1.8

# %%
xnew.isna().sum()
# Out:
# sepal_length    0
# sepal_width     1
# petal_length    1
# petal_width     1
# dtype: int64

# %% [markdown]
# ## Preprocess and clean your out of sample data

# %%
model.predict(xnew)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 model.predict(xnew)
#
# File c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\linear_model\_base.py:375, in LinearClassifierMixin.predict(self, X)
#     361 """
#     362 Predict class labels for samples in X.
#     363
#    (...)    372     Vector containing the class labels for each sample.
#     373 """
#     374 xp, _ = get_namespace(X)
# --> 375 scores = self.decision_function(X)
#     376 if len(scores.shape) == 1:
#     377     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\linear_model\_base.py:352, in LinearClassifierMixin.decision_function(self, X)
#     349 check_is_fitted(self)
#     350 xp, _ = get_namespace(X)
# --> 352 X = validate_data(self, X, accept_sparse="csr", reset=False)
#     353 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     354 return (
#     355     xp.reshape(scores, (-1,))
#     356     if (scores.ndim > 1 and scores.shape[1] == 1)
#     357     else scores
#     358 )
#
# File c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\utils\validation.py:2954, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2952         out = X, y
#    2953 elif not no_val_X and no_val_y:
# -> 2954     out = check_array(X, input_name="X", **check_params)
#    2955 elif no_val_X and not no_val_y:
#    2956     out = _check_y(y, **check_params)
#
# File c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\utils\validation.py:1105, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
# -> 1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#    1112 if copy:
#    1113     if _is_numpy_namespace(xp):
#    1114         # only make a copy if `array` and `array_orig` may share memory`
#
# File c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\utils\validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\utils\validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
pre
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler())])

# %%
xnew_pre = pre.transform(xnew)
xnew_pre.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0     -0.414976    -1.287108      0.142468     0.138633
# 1      1.275726     0.092598      0.766812     1.454321
# 2     -0.898033    -1.287108     -0.425118    -0.124505
# 3     -1.743384    -0.367304      0.312744    -1.308624
# 4      0.068082    -0.137353      0.766812     0.796477

# %% [markdown]
# ## Final Predictions

# %%
species_predicted = model.predict(xnew_pre)

# %%
species_predicted
# Out:
# array(['versicolor', 'virginica', 'versicolor', 'setosa', 'virginica',
#        'setosa', 'versicolor', 'virginica', 'setosa', 'setosa',
#        'versicolor', 'versicolor', 'virginica', 'versicolor',
#        'versicolor'], dtype=object)

# %%
xnew
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 0            5.5          2.5           4.0          1.3
# 1            6.9          3.1           5.1          2.3
# 2            5.1          2.5           3.0          1.1
# 3            4.4          2.9           NaN          0.2
# 4            5.9          3.0           5.1          1.8
# 5            5.5          3.5           1.3          0.2
# 6            5.6          NaN           3.6          1.3
# 7            6.5          3.0           5.2          2.0
# 8            5.3          3.7           1.5          0.2
# 9            5.1          3.4           1.5          NaN
# 10           6.1          2.8           4.0          1.3
# 11           5.5          2.4           3.7          1.0
# 12           7.7          3.0           6.1          2.3
# 13           6.9          3.1           4.9          1.5
# 14           6.0          2.2           5.0          1.5

# %%
xnew['predicted_species'] = species_predicted

# %%
xnew
# Out:
#     sepal_length  sepal_width  petal_length  petal_width predicted_species
# 0            5.5          2.5           4.0          1.3        versicolor
# 1            6.9          3.1           5.1          2.3         virginica
# 2            5.1          2.5           3.0          1.1        versicolor
# 3            4.4          2.9           NaN          0.2            setosa
# 4            5.9          3.0           5.1          1.8         virginica
# 5            5.5          3.5           1.3          0.2            setosa
# 6            5.6          NaN           3.6          1.3        versicolor
# 7            6.5          3.0           5.2          2.0         virginica
# 8            5.3          3.7           1.5          0.2            setosa
# 9            5.1          3.4           1.5          NaN            setosa
# 10           6.1          2.8           4.0          1.3        versicolor
# 11           5.5          2.4           3.7          1.0        versicolor
# 12           7.7          3.0           6.1          2.3         virginica
# 13           6.9          3.1           4.9          1.5        versicolor
# 14           6.0          2.2           5.0          1.5        versicolor

# %%
xnew.to_csv("Iris Species Predicted.csv",index=False)
