# %% [markdown]
# ## Simple Linear Regression

# %%
import pandas as pd

# %%
path = r"https://raw.githubusercontent.com/sindhura-nk/Datasets/refs/heads/main/50_Startups.csv"
df = pd.read_csv(path)
df.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RND     50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   MKT     50 non-null     float64
#  3   STATE   50 non-null     object
#  4   PROFIT  50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# ## Data Cleaning

# %%
df.isna().sum()
# Out:
# RND       0
# ADMIN     0
# MKT       0
# STATE     0
# PROFIT    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Separate X and Y features
#     X: Independent feature => RND
#     Y: Dependent feature => PROFIT

# %%
df['RND']
# Out:
# 0     165349.20
# 1     162597.70
# 2     153441.51
# 3     144372.41
# 4     142107.34
# 5     131876.90
# 6     134615.46
# 7     130298.13
# 8     120542.52
# 9     123334.88
# 10    101913.08
# 11    100671.96
# 12     93863.75
# 13     91992.39
# 14    119943.24
# 15    114523.61
# 16     78013.11
# 17     94657.16
# 18     91749.16
# 19     86419.70
# 20     76253.86
# 21     78389.47
# 22     73994.56
# 23     67532.53
# 24     77044.01
# 25     64664.71
# 26     75328.87
# 27     72107.60
# 28     66051.52
# 29     65605.48
# 30     61994.48
# 31     61136.38
# 32     63408.86
# 33     55493.95
# 34     46426.07
# 35     46014.02
# 36     28663.76
# 37     44069.95
# 38     20229.59
# 39     38558.51
# 40     28754.33
# 41     27892.92
# 42     23640.93
# 43     15505.73
# 44     22177.74
# 45      1000.23
# 46      1315.46
# 47         0.00
# 48       542.05
# 49         0.00
# Name: RND, dtype: float64

# %%
df[['RND']]
# Out:
#           RND
# 0   165349.20
# 1   162597.70
# 2   153441.51
# 3   144372.41
# 4   142107.34
# 5   131876.90
# 6   134615.46
# 7   130298.13
# 8   120542.52
# 9   123334.88
# 10  101913.08
# 11  100671.96
# 12   93863.75
# 13   91992.39
# 14  119943.24
# 15  114523.61
# 16   78013.11
# 17   94657.16
# 18   91749.16
# 19   86419.70
# 20   76253.86
# 21   78389.47
# 22   73994.56
# 23   67532.53
# 24   77044.01
# 25   64664.71
# 26   75328.87
# 27   72107.60
# 28   66051.52
# 29   65605.48
# 30   61994.48
# 31   61136.38
# 32   63408.86
# 33   55493.95
# 34   46426.07
# 35   46014.02
# 36   28663.76
# 37   44069.95
# 38   20229.59
# 39   38558.51
# 40   28754.33
# 41   27892.92
# 42   23640.93
# 43   15505.73
# 44   22177.74
# 45    1000.23
# 46    1315.46
# 47       0.00
# 48     542.05
# 49       0.00

# %%
X = df[['RND']]
Y = df[['PROFIT']]

# %%
X.head()
# Out:
#          RND
# 0  165349.20
# 1  162597.70
# 2  153441.51
# 3  144372.41
# 4  142107.34

# %%
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %% [markdown]
# ### There are no missing values nor any duplicated rows in this dataset

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer

# %%
pipe = make_pipeline(SimpleImputer(strategy='median')).set_output(transform='pandas')

# %%
pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median'))])

# %% [markdown]
#     fit_transform: fit the data and transform the data based on provided conditions
#     tranform : will do only the changes
#     fit: will only fit the changes

# %%
df.dtypes
# Out:
# RND       float64
# ADMIN     float64
# MKT       float64
# STATE      object
# PROFIT    float64
# dtype: object

# %%
#pipe.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 pipe.fit_transform(df)
#
# File c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\pipeline.py:731, in Pipeline.fit_transform(self, X, y, **params)
#     725 last_step_params = self._get_metadata_for_step(
#     726     step_idx=len(self) - 1,
#     727     step_params=routed_params[self.steps[-1][0]],
#     728     all_params=params,
#     729 )
#     730 if hasattr(last_step, "fit_transform"):
# --> 731     return last_step.fit_transform(
#     732         Xt, y, **last_step_params["fit_transform"]
#     733     )
#     734 else:
#     735     return last_step.fit(Xt, y, **last_step_params["fit"]).transform(
#     736         Xt, **last_step_params["transform"]
#     737     )
#
# File c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\base.py:894, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     879         warnings.warn(
#     880             (
#     881                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    889             UserWarning,
#     890         )
#     892 if y is None:
#     893     # fit method of arity 1 (unsupervised transformation)
# --> 894     return self.fit(X, **fit_params).transform(X)
#     895 else:
#     896     # fit method of arity 2 (supervised transformation)
#     897     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\impute\_base.py:436, in SimpleImputer.fit(self, X, y)
#     418 @_fit_context(prefer_skip_nested_validation=True)
#     419 def fit(self, X, y=None):
#     420     """Fit the imputer on `X`.
#     421
#     422     Parameters
#    (...)    434         Fitted estimator.
#     435     """
# --> 436     X = self._validate_input(X, in_fit=True)
#     438     # default fill_value is 0 for numerical input and "missing_value"
#     439     # otherwise
#     440     if self.fill_value is None:
#
# File c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\impute\_base.py:361, in SimpleImputer._validate_input(self, X, in_fit)
#     355 if "could not convert" in str(ve):
#     356     new_ve = ValueError(
#     357         "Cannot use {} strategy with non-numeric data:\n{}".format(
#     358             self.strategy, ve
#     359         )
#     360     )
# --> 361     raise new_ve from None
#     362 else:
#     363     raise ve
#
# ValueError: Cannot use median strategy with non-numeric data:
# could not convert string to float: 'New York'

# %%
X_pre = pipe.fit_transform(X)
X_pre.head()
# Out:
#          RND
# 0  165349.20
# 1  162597.70
# 2  153441.51
# 3  144372.41
# 4  142107.34

# %% [markdown]
# ## Model Building : Linear Regression
#     Equation of Line: y = B0 + B1.X
#     B0 => y intercept
#     B1 => Slope of the line
#
#     ProfitPredicted = B0 + B1*RND

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
# B0- y intercept
model.intercept_
# Out:
# array([49032.89914125])

# %%
# B1- slope of the line
model.coef_
# Out:
# array([[0.85429137]])

# %% [markdown]
# ProfitPredicted = 49032.9 + 0.8542*RND
#
# RND=0
# ProfitPredicted = 49032.9
#
# Rnd=1
# It will increase by 0.854 times

# %%
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
Ypreds = model.predict(X)
Ypreds
# Out:
# array([[190289.29389289],
#        [187938.71118575],
#        [180116.65707807],
#        [172369.00320589],
#        [170433.97345032],
#        [161694.19683741],
#        [164033.72501421],
#        [160345.46724972],
#        [152011.33380847],
#        [154396.82286103],
#        [136096.36397105],
#        [135036.08586475],
#        [129219.89081021],
#        [127621.20411029],
#        [151499.37407569],
#        [146869.43093301],
#        [115678.82583435],
#        [129897.69412683],
#        [127413.41482014],
#        [122860.50313037],
#        [114175.91374003],
#        [116000.34693472],
#        [112245.81324567],
#        [106725.35677792],
#        [114850.93206678],
#        [104275.40289851],
#        [113385.70276482],
#        [110633.79960036],
#        [105460.14271464],
#        [105079.09459155],
#        [101994.24845109],
#        [101261.18102569],
#        [103202.54108032],
#        [ 96440.90176556],
#        [ 88694.29012885],
#        [ 88342.27936946],
#        [ 73520.10196791],
#        [ 86681.47714396],
#        [ 66314.86331588],
#        [ 81973.10151051],
#        [ 73597.47513738],
#        [ 72861.58000754],
#        [ 69229.14164122],
#        [ 62279.31048036],
#        [ 67979.15105018],
#        [ 49887.38699921],
#        [ 50156.68526807],
#        [ 49032.89914125],
#        [ 49495.96777887],
#        [ 49032.89914125]])

# %%
Ypreds[0:5]
# Out:
# array([[190289.29389289],
#        [187938.71118575],
#        [180116.65707807],
#        [172369.00320589],
#        [170433.97345032]])

# %%
Ypreds[:5]
# Out:
# array([[190289.29389289],
#        [187938.71118575],
#        [180116.65707807],
#        [172369.00320589],
#        [170433.97345032]])

# %%
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %% [markdown]
# ## Evaluation Metrics
#     Mean Squared Error
#     Mean Absolute Error
#     RMSE
#     R2 squared- R2 score

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
# Mean Squared Error
MSE = mean_squared_error(Y,Ypreds)
# RMSE - Root mean squared error
RMSE = MSE**(1/2)
# MAE 
MAE = mean_absolute_error(Y,Ypreds)
# R2 score
r2 = r2_score(Y,Ypreds)

print(f"Mean Squared Error: {MSE:.2f}")
print(f"Root Mean Squared Error: {RMSE:.2f}")
print(f"Mean Absolute Error: {MAE:.2f}")
print(f"R2 squared: {r2*100:.2f}%")
# Out:
# Mean Squared Error: 85120931.33
# Root Mean Squared Error: 9226.10
# Mean Absolute Error: 6910.98
# R2 squared: 94.65%

# %% [markdown]
# ## R2 squared value is greater than 80%, we can consider this model for final model building

# %%
rnd_sample = [160045,178000,187000,198650]

# %%
preds = []
for x in rnd_sample:
    pred = model.predict([[x]]).round(2)
    preds.append(pred)
# Out:
# c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\HP\anaconda3\envs\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
rnd_sample
# Out:
# [160045, 178000, 187000, 198650]

# %%
print(preds)
# Out:
# [array([[185757.96]]), array([[201096.76]]), array([[208785.39]]), array([[218737.88]])]
